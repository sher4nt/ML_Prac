# %%
import numpy as np
import pandas as pd

import xgboost as xgb
from sklearn.ensemble import RandomForestClassifier

# %%
train = pd.read_csv("train_sample.csv")
test = pd.read_csv("test_sample.csv")

# %%
train.head()
# Out:
#          X1        X2        X3        X4        X5        X6        X7  class
# 0  0.746933  0.161885  0.140955  0.583561  0.144622  0.336816  0.264085      1
# 1  0.685185  0.543761  0.123296  0.692514  0.291902  0.005400  0.403936      0
# 2  0.245476  0.051729  0.269197  0.864631  0.055845  0.226046  0.643894      0
# 3  0.284447  0.052023  0.194530  0.554029  0.204384  0.674742  0.584669      0
# 4  0.451972  0.858497  0.320467  0.665244  0.427009  0.662678  0.834946      1

# %%
test.head()
# Out:
#          X1        X2        X3        X4        X5        X6        X7
# 0  0.703602  0.291032  0.973082  0.111220  0.486934  0.565759  0.386211
# 1  0.016245  0.050978  0.476517  0.472171  0.686417  0.113717  0.655804
# 2  0.452641  0.201385  0.352279  0.938298  0.525925  0.171441  0.857071
# 3  0.628356  0.267784  0.186499  0.208748  0.780065  0.097353  0.475235
# 4  0.849251  0.957766  0.093711  0.256294  0.870455  0.068927  0.320942

# %%
X_train, y_train = train.drop('class', axis=1), train['class']

# %%
param = {'objective': 'binary:logistic', 'eval_metric': 'auc'}

cross_val = xgb.cv(
    params=param,
    dtrain=xgb.DMatrix(X_train, label=y_train),
    seed=0,
    nfold=5,
    num_boost_round=100
)

# %%
best_rounds = np.argmax(cross_val['test-auc-mean'])
print(best_rounds, np.max(cross_val['test-auc-mean']))
# Out:
# 24 0.9393060705367728

# %%
model = xgb.train(param, xgb.DMatrix(X_train, label=y_train), num_boost_round=best_rounds)
y_pred = model.predict(xgb.DMatrix(test))

# %%
model = RandomForestClassifier(random_state=0)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
model.feature_importances_
# Out:
# array([0.57836221, 0.06427951, 0.06629757, 0.07772673, 0.06671917,
#        0.07818515, 0.06842967])

# %%
t = pd.Series(model.feature_importances_, index=range(1,8))
rf_most_important = t.sort_values(ascending=False).index
rf_most_important
# Out:
# Int64Index([1, 6, 4, 7, 5, 3, 2], dtype='int64')

# %%
np.savez('submission.npz', rf_most_important=rf_most_important[0],
         prediction=y_pred)

# %%
data = np.load('submission.npz')
lst = data.files
for item in lst:
    print(item)
    print(data[item])
# Out:
# rf_most_important
# 1
# prediction
# [0.994103   0.01267427 0.9957781  0.9112735  0.87001777 0.06064529
#  0.01179479 0.00875699 0.9909697  0.04080543 0.99591714 0.9782938
#  0.00567097 0.9949314  0.1803479  0.01792809 0.9983175  0.02464544
#  0.99408567 0.99678934 0.00309285 0.99543744 0.9929877  0.7400381
#  0.91603863 0.9882901  0.14201933 0.98458004 0.07420897 0.5437598
#  0.89169204 0.99608386 0.01646675 0.99687517 0.17823173 0.98641336
#  0.03268986 0.02283901 0.996741   0.61895025 0.9604924  0.98894626
#  0.43994385 0.12661028 0.21009548 0.05027382 0.9944013  0.06243235
#  0.9938677  0.9813793  0.181149   0.97952497 0.06839682 0.00664827
#  0.0342198  0.9975153  0.9108474  0.98865885 0.25719285 0.99223644
#  0.97787696 0.03898548 0.9601598  0.98909163 0.19721024 0.0089342
#  0.855233   0.9928295  0.8348242  0.9975756  0.9941695  0.95225513
#  0.00261485 0.9813571  0.5172491  0.0056642  0.11035867 0.04053485
#  0.9950759  0.01500657 0.9928197  0.92088705 0.01873994 0.9943013
#  0.9797499  0.05535256 0.9883463  0.9861691  0.9959811  0.01439059
#  0.04438873 0.40973955 0.01013402 0.98525304 0.17670603 0.00379024
#  0.01270326 0.8800863  0.7062253  0.36522323 0.97425336 0.8446998
#  0.9943197  0.00683147 0.99152184 0.05253266 0.00493592 0.00452434
#  0.9831139  0.9114784  0.99318177 0.9700749  0.9912844  0.08403098
#  0.98949534 0.934627   0.97914416 0.07977197 0.02395133 0.170665
#  0.17566767 0.82874006 0.99362385 0.9350036  0.5230955  0.07504734
#  0.51945114 0.98488903 0.02311949 0.14061938 0.04382068 0.19430289
#  0.97348714 0.98901075 0.66882366 0.00529548 0.00711761 0.6463928
#  0.9971294  0.00324683 0.45774284 0.99134713 0.02118897 0.9896175
#  0.00904583 0.99803334 0.9690893  0.01749601 0.48596358 0.00950371
#  0.99603516 0.00361021 0.05398757 0.00480305 0.99458486 0.9890764
#  0.1179629  0.73727494 0.60826224 0.9883343  0.9865841  0.0025416
#  0.99287635 0.9954299  0.943939   0.9975165  0.9943547  0.99615544
#  0.9752142  0.98638165 0.19642949 0.95960975 0.30086207 0.9554862
#  0.78653365 0.0169603  0.00436711 0.955868   0.30881017 0.996801
#  0.9942356  0.00523579 0.9916088  0.6803864  0.06609756 0.9935875
#  0.00954385 0.08460296 0.4554029  0.9970995  0.97185475 0.9958727
#  0.9967775  0.9970475  0.99580175 0.46107832 0.05345787 0.98926264
#  0.9349725  0.12440292 0.76749194 0.00426618 0.97464585 0.98999757
#  0.984479   0.8982115  0.99640685 0.2564928  0.99324894 0.8899884
#  0.01238638 0.12665856 0.02759476 0.47400346 0.00745798 0.99330705
#  0.9983975  0.01819566 0.4014069  0.00267882 0.9955337  0.00320975
#  0.5680747  0.19262297 0.03888185 0.37143883 0.9965848  0.9917177
#  0.09327271 0.9911731  0.9928808  0.20225875 0.62455916 0.8391515
#  0.01478077 0.8562593  0.9641503  0.99570054 0.00532643 0.9887543
#  0.71147245 0.9951763  0.9783211  0.44606987 0.9975345  0.01607026
#  0.00680523 0.9959335  0.99798125 0.09895501 0.2188841  0.9085881
#  0.01165884 0.00290692 0.9630651  0.36914086 0.00269668 0.9287272
#  0.9979087  0.99427843 0.02072571 0.5208148  0.9943909  0.97017246
#  0.98453254 0.5374036  0.9849433  0.00440232 0.98285025 0.06293916
#  0.15358746 0.20314209 0.993519   0.00351716 0.9171078  0.98092425
#  0.99773717 0.98971224 0.70646006 0.089758   0.00780839 0.99135077
#  0.995076   0.01255744 0.9666511  0.9730453  0.997895   0.99068415
#  0.75188345 0.99025714 0.9860119  0.29718453 0.9917012  0.2519611
#  0.98934454 0.01131335 0.9765976  0.07763264 0.9960802  0.997872
#  0.986943   0.14441106 0.02218028 0.9958768  0.715162   0.25425228
#  0.71018195 0.05562095 0.9297635  0.04662928 0.99528944 0.95305187
#  0.8601896  0.74456626 0.9955941  0.9113374  0.02376857 0.06627347
#  0.02256885 0.00754288 0.96242875 0.16864267 0.7700188  0.06542902
#  0.00629066 0.9715872  0.26243266 0.01828911 0.08505364 0.36486626
#  0.9978834  0.01019655 0.9958609  0.99095505 0.00652634 0.9866788
#  0.99441224 0.01674369 0.9466934  0.99242485 0.01731384 0.24136773
#  0.9516094  0.9824607  0.99358    0.34881777 0.93707657 0.96869016
#  0.9547715  0.9971294  0.97695255 0.00288466 0.9674751  0.94461405
#  0.99665314 0.01517519 0.987336   0.09592808 0.01725902 0.9477516
#  0.9694966  0.04259606 0.99598396 0.9969025  0.99686605 0.99778867
#  0.9880802  0.98455876 0.9747243  0.00736546 0.8528264  0.9856883
#  0.79479605 0.9966137  0.9947754  0.99299777 0.01483575 0.9780959
#  0.00246963 0.03575115 0.00910192 0.99615246 0.98350555 0.00485812
#  0.5003478  0.1143671  0.0122071  0.31248087 0.99751794 0.83122516
#  0.35257927 0.8512696  0.9969265  0.6180053  0.9905013  0.87697375
#  0.9955615  0.0361049  0.07147249 0.00813573 0.9963211  0.01010102
#  0.02729678 0.00462619 0.74299425 0.02953639 0.8934648  0.97946495
#  0.9944929  0.9974896  0.0916137  0.99813974 0.17689666 0.4215713
#  0.9942673  0.06511699 0.01766561 0.7770052  0.99371994 0.01812398
#  0.00702763 0.8821935  0.98705894 0.01238765 0.00630089 0.9725151
#  0.00586528 0.9930583  0.50346726 0.5850033  0.08881085 0.7020738
#  0.99796224 0.0150934  0.9930265  0.00273331 0.9903341  0.04683722
#  0.9332037  0.98927796 0.07937432 0.9926472  0.99458236 0.01069587
#  0.99173146 0.963903   0.960845   0.00874771 0.9957877  0.99736917
#  0.99633175 0.06392927 0.99710935 0.98027086 0.98673207 0.01451623
#  0.9421684  0.80447274 0.9252991  0.05918908 0.9944043  0.96678823
#  0.8915407  0.94549763 0.9739028  0.9969246  0.99245125 0.9744323
#  0.95933    0.88352114 0.00758811 0.995865   0.02199192 0.43445203
#  0.996179   0.9922178  0.00342514 0.07301039 0.96093905 0.99384576
#  0.9678216  0.8744126  0.9971852  0.978774   0.9946196  0.9861037
#  0.01173886 0.8513158  0.00478991 0.86575    0.00400681 0.1354447
#  0.01036419 0.9829653  0.93177444 0.78663987 0.01505085 0.99754804
#  0.99369144 0.03015738]

# %%
npzfile = np.load('submission.npz')
print(npzfile['rf_most_important'],npzfile['prediction'].shape)
# Out:
# 1 (500,)
